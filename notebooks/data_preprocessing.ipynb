# %%
import pandas as pd
import numpy as np
import pickle

# %%
# Accessing the research papers and data

with open('data/metadata_sample.pickle', 'rb') as f:
  df_metadata = pickle.load(f)
with open('data/json_pdf_sample.pickle', 'rb') as f:
  df_pdf = pickle.load(f)
with open('data/json_pmc_sample.pickle', 'rb') as f:
  df_pmc = pickle.load(f)

# %%
df_metadata.head()
# Out:
#         cord_uid                                                sha  \
# 819514  iyyq4idj  82df15cd2620c224affd4ce100e7fac7fcff7b10; 67f7...
# 611388  h1juos01           1e7e71936cb8aa74a8c9e8ba90c5d729dec7f405
# 19784   awql4vol           cc4e338a21138f18ef26af7b26c5ecc28270d959
# 789340  tynn8700           3114420bfc07e18049a9e7045b42c4de7a30bb81
# 779704  z6bkoheb           1ef3ec3dfb9bea22c1060c1c469fc1de5c41f15a
#
#                  source_x                                              title  \
# 819514       Medline; PMC  Deconvoluting Lipid Nanoparticle Structure for...
# 611388  Medline; PMC; WHO            Predictability in Contemporary Medicine
# 19784                 PMC  Experimental Models of Hepatocellular Carcinom...
# 789340  Medline; PMC; WHO  Cancer and COVID-19: analysis of patient outcomes
# 779704  Medline; PMC; WHO  Haematuria, a widespread petechial rash, and h...
#
#                                  doi       pmcid   pubmed_id license  \
# 819514  10.1021/acs.nanolett.0c01386  PMC7228479  32375002.0   no-cc
# 611388      10.3389/fmed.2021.510421  PMC8242575  34222267.0   cc-by
# 19784        10.3390/cancers13153651  PMC8344976    34359553   cc-by
# 789340         10.2217/fon-2021-0121  PMC8284249  34263660.0   cc-by
# 779704       10.1136/bcr-2021-245440  PMC8499345  34620638.0   no-cc
#
#                                                  abstract publish_time  \
# 819514  [Image: see text] Lipid nanoparticle (LNP) pac...   2020-05-06
# 611388  Medical practice is increasingly coming under ...   2021-06-16
# 19784   SIMPLE SUMMARY: Hepatocellular carcinoma (HCC)...   2021-07-21
# 789340  Background: We sought to investigate the outco...   2021-07-15
# 779704  With increasing presentations of headaches fol...   2021-10-07
#
#                                                   authors  \
# 819514  Eygeris, Yulia; Patel, Siddharth; Jozic, Anton...
# 611388                                 Ciulla, Michele M.
# 19784   Blidisel, Alexandru; Marcovici, Iasmina; Coric...
# 789340  Aboueshia, Mohamed; Hussein, Mohammad Hosny; A...
# 779704                   Waraich, Ammar; Williams, George
#
#                      journal  mag_id who_covidence_id arxiv_id  \
# 819514             Nano Lett     NaN              NaN      NaN
# 611388  Front Med (Lausanne)     NaN              NaN      NaN
# 19784        Cancers (Basel)     NaN              NaN      NaN
# 789340       Future oncology     NaN              NaN      NaN
# 779704          BMJ Case Rep     NaN              NaN      NaN
#
#                                            pdf_json_files  \
# 819514  document_parses/pdf_json/82df15cd2620c224affd4...
# 611388  document_parses/pdf_json/1e7e71936cb8aa74a8c9e...
# 19784   document_parses/pdf_json/cc4e338a21138f18ef26a...
# 789340  document_parses/pdf_json/3114420bfc07e18049a9e...
# 779704  document_parses/pdf_json/1ef3ec3dfb9bea22c1060...
#
#                                       pmc_json_files  \
# 819514  document_parses/pmc_json/PMC7228479.xml.json
# 611388  document_parses/pmc_json/PMC8242575.xml.json
# 19784   document_parses/pmc_json/PMC8344976.xml.json
# 789340  document_parses/pmc_json/PMC8284249.xml.json
# 779704  document_parses/pmc_json/PMC8499345.xml.json
#
#                                                       url        s2_id
# 819514  https://doi.org/10.1021/acs.nanolett.0c01386; ...  218535340.0
# 611388  https://www.ncbi.nlm.nih.gov/pubmed/34222267/;...  235441458.0
# 19784   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8...          NaN
# 789340  https://www.ncbi.nlm.nih.gov/pubmed/34263660/;...  235907629.0
# 779704  https://www.ncbi.nlm.nih.gov/pubmed/34620638/;...  238475067.0

# %% [markdown]
# #### Data Merging (merging the data from metadata, json pdf and json pmc files for research papers)

# %%
#Merging the metadata and json pdf data
#sha column of metadata and paper_id of json_pdf data are same identifier for each record
df_merged = pd.merge(df_metadata,df_pdf,left_on='sha',right_on='paper_id',how='left').drop('paper_id',axis=1)

# %%
df_merged.head(2)
#abstract_x is the abstract from metadata and abstract_y is the abstract from json_pdf
# Out:
#    cord_uid                                                sha  \
# 0  iyyq4idj  82df15cd2620c224affd4ce100e7fac7fcff7b10; 67f7...
# 1  h1juos01           1e7e71936cb8aa74a8c9e8ba90c5d729dec7f405
#
#             source_x                                              title  \
# 0       Medline; PMC  Deconvoluting Lipid Nanoparticle Structure for...
# 1  Medline; PMC; WHO            Predictability in Contemporary Medicine
#
#                             doi       pmcid   pubmed_id license  \
# 0  10.1021/acs.nanolett.0c01386  PMC7228479  32375002.0   no-cc
# 1      10.3389/fmed.2021.510421  PMC8242575  34222267.0   cc-by
#
#                                           abstract_x publish_time  ...  \
# 0  [Image: see text] Lipid nanoparticle (LNP) pac...   2020-05-06  ...
# 1  Medical practice is increasingly coming under ...   2021-06-16  ...
#
#                 journal mag_id  who_covidence_id arxiv_id  \
# 0             Nano Lett    NaN               NaN      NaN
# 1  Front Med (Lausanne)    NaN               NaN      NaN
#
#                                       pdf_json_files  \
# 0  document_parses/pdf_json/82df15cd2620c224affd4...
# 1  document_parses/pdf_json/1e7e71936cb8aa74a8c9e...
#
#                                  pmc_json_files  \
# 0  document_parses/pmc_json/PMC7228479.xml.json
# 1  document_parses/pmc_json/PMC8242575.xml.json
#
#                                                  url        s2_id  \
# 0  https://doi.org/10.1021/acs.nanolett.0c01386; ...  218535340.0
# 1  https://www.ncbi.nlm.nih.gov/pubmed/34222267/;...  235441458.0
#
#                                           abstract_y  \
# 0                                                NaN
# 1  Medical practice is increasingly coming under ...
#
#                                            body_text
# 0                                                NaN
# 1  The aim of this paper is to present in a histo...
#
# [2 rows x 21 columns]

# %%
#Lets merge the json_pmc data to the merged data too
df_merged = pd.merge(df_merged,df_pmc,left_on='pmcid',right_on='paper_id',how='left').drop('paper_id',axis=1)
df_merged.shape
# Out:
# (30000, 22)

# %% [markdown]
# ##### Data Cleaning and Preprocessing

# %%
df_merged[df_merged.abstract_x != df_merged.abstract_y].shape
# Out:
# (27221, 22)

# %%
# check metadata abstract column to see if null values exist
df_merged.abstract_x.isnull().sum(),(df_merged.abstract_x == '').sum()
# Out:
# (4269, 0)

# %%
# Check pdf_json abstract to see if null values exist
df_merged.abstract_y.isnull().sum(),(df_merged.abstract_y == '').sum()
# Out:
# (1836, 8166)

# %% [markdown]
# Since the abstract_x from metadata is more reliable , we will use it but only fill by abstract_y text when abstract_x value is null

# %%
# Convert all columns to string and then replace abstract_y values
#df = df.astype(str)
df_merged["abstract_y"] = df_merged["abstract_y"].astype(str) 
df_merged['abstract_y'] = np.where(df_merged['abstract_y'].map(len) > 50, df_merged['abstract_y'], "na")

# %%
df_merged[df_merged['abstract_y'].apply(lambda x: len(str(x)) <= 10)]
# Out:
#        cord_uid                                                sha  \
# 0      iyyq4idj  82df15cd2620c224affd4ce100e7fac7fcff7b10; 67f7...
# 8      pov7ipwy           085c356124bb58ba18b5255cd884c82fb4888cc6
# 11     sne2o5y3           bc32a5a720d9721dcabf8f69081a63a3efa5fdcb
# 12     mivv87nd           598a4b91b51070095c7c25e79b7f198d604f09e7
# 18     jmdxjpyq  1928a032224b22aa192550c7e58dc71e190901df; b6cf...
# ...         ...                                                ...
# 29986  ig6ff0kd           bcf0f876cf7f8fefc104c078b22b6aafa2f04d9b
# 29988  7pxvzrq8           b800e9051e17e929973706bc55e4ea6b7abba667
# 29990  jasgmk4h           28c766fb31fbb27728121efc65c884b52831f4ea
# 29997  fn8fuzvo           df3052bd12a69ef76897506b25bc4e5f7b008467
# 29999  o40ey199  20ccde51feef6bc97b383a9a53f17ef09e8de1a5; 8d63...
#
#                      source_x  \
# 0                Medline; PMC
# 8           Medline; PMC; WHO
# 11     Elsevier; Medline; PMC
# 12              Elsevier; PMC
# 18               Medline; PMC
# ...                       ...
# 29986            Medline; PMC
# 29988                 MedRxiv
# 29990       Medline; PMC; WHO
# 29997       Medline; PMC; WHO
# 29999            Medline; PMC
#
#                                                    title  \
# 0      Deconvoluting Lipid Nanoparticle Structure for...
# 8      Attitude Towards COVID-19 Vaccination Among He...
# 11                               The proper use of masks
# 12               Musculoskeletal and Neurologic Diseases
# 18     Clinical prediction rule for SARS-CoV-2 infect...
# ...                                                  ...
# 29986  Technology, Population Health, and Human Wellness
# 29988  Non-invasive Vagus Nerve Stimulation for Respi...
# 29990  Consequences of the COVID-19 Lockdown in Germa...
# 29997  Regionales Monitoring von Infektionen mittels ...
# 29999  COVID-19 pandemic and therapy with ibuprofen o...
#
#                                       doi       pmcid   pubmed_id    license  \
# 0            10.1021/acs.nanolett.0c01386  PMC7228479  32375002.0      no-cc
# 8                     10.2147/idr.s332792  PMC8464326  34584432.0   cc-by-nc
# 11             10.1016/j.banm.2020.09.028  PMC7501773  32981936.0  els-covid
# 12     10.1016/b978-0-323-48435-0.00010-1  PMC7258713         NaN      no-cc
# 18           10.1371/journal.pone.0248438  PMC7946184  33690722.0      cc-by
# ...                                   ...         ...         ...        ...
# 29986          10.1007/s41745-020-00207-z  PMC7643103  33169052.0      no-cc
# 29988         10.1101/2021.09.24.21264045         NaN         NaN    medrxiv
# 29990             10.3390/ijerph181910463  PMC8507817  34639763.0      cc-by
# 29997          10.1007/s00103-021-03397-8  PMC8358915  34383083.0      cc-by
# 29999          10.1007/s00210-020-01890-6  PMC7225250  32415494.0      cc-by
#
#                                               abstract_x publish_time  ...  \
# 0      [Image: see text] Lipid nanoparticle (LNP) pac...   2020-05-06  ...
# 8      INTRODUCTION: Availability and accessibility o...   2021-09-21  ...
# 11                                                   NaN   2020-09-19  ...
# 12     Ferrets may exhibit neurologic signs as a resu...   2020-05-29  ...
# 18     OBJECTIVES: Accurate and reliable criteria to ...   2021-03-10  ...
# ...                                                  ...          ...  ...
# 29986                                                NaN   2020-11-05  ...
# 29988  Background: Severe coronavirus disease 2019 (C...   2021-09-27  ...
# 29990  The current study investigated how music has b...   2021-10-05  ...
# 29997  BACKGROUND: Maps of the temporal evolution of ...   2021-08-12  ...
# 29999  Scientists hypothesized that drugs such as ibu...   2020-05-15  ...
#
#       mag_id who_covidence_id  arxiv_id  \
# 0        NaN              NaN       NaN
# 8        NaN              NaN       NaN
# 11       NaN              NaN       NaN
# 12       NaN              NaN       NaN
# 18       NaN              NaN       NaN
# ...      ...              ...       ...
# 29986    NaN              NaN       NaN
# 29988    NaN              NaN       NaN
# 29990    NaN              NaN       NaN
# 29997    NaN              NaN       NaN
# 29999    NaN              NaN       NaN
#
#                                           pdf_json_files  \
# 0      document_parses/pdf_json/82df15cd2620c224affd4...
# 8      document_parses/pdf_json/085c356124bb58ba18b52...
# 11     document_parses/pdf_json/bc32a5a720d9721dcabf8...
# 12     document_parses/pdf_json/598a4b91b51070095c7c2...
# 18     document_parses/pdf_json/1928a032224b22aa19255...
# ...                                                  ...
# 29986  document_parses/pdf_json/bcf0f876cf7f8fefc104c...
# 29988  document_parses/pdf_json/b800e9051e17e92997370...
# 29990  document_parses/pdf_json/28c766fb31fbb27728121...
# 29997  document_parses/pdf_json/df3052bd12a69ef768975...
# 29999  document_parses/pdf_json/20ccde51feef6bc97b383...
#
#                                      pmc_json_files  \
# 0      document_parses/pmc_json/PMC7228479.xml.json
# 8      document_parses/pmc_json/PMC8464326.xml.json
# 11                                              NaN
# 12     document_parses/pmc_json/PMC7258713.xml.json
# 18     document_parses/pmc_json/PMC7946184.xml.json
# ...                                             ...
# 29986  document_parses/pmc_json/PMC7643103.xml.json
# 29988                                           NaN
# 29990  document_parses/pmc_json/PMC8507817.xml.json
# 29997  document_parses/pmc_json/PMC8358915.xml.json
# 29999  document_parses/pmc_json/PMC7225250.xml.json
#
#                                                      url        s2_id  \
# 0      https://doi.org/10.1021/acs.nanolett.0c01386; ...  218535340.0
# 8      https://www.ncbi.nlm.nih.gov/pubmed/34584432/;...  238199445.0
# 11     https://doi.org/10.1016/j.banm.2020.09.028; ht...  221796386.0
# 12     https://api.elsevier.com/content/article/pii/B...  218973161.0
# 18     https://www.ncbi.nlm.nih.gov/pubmed/33690722/;...  232193176.0
# ...                                                  ...          ...
# 29986  https://doi.org/10.1007/s41745-020-00207-z; ht...  226248297.0
# 29988  http://medrxiv.org/cgi/content/short/2021.09.2...  237941228.0
# 29990  https://www.ncbi.nlm.nih.gov/pubmed/34639763/;...  238741717.0
# 29997  https://www.ncbi.nlm.nih.gov/pubmed/34383083/;...  236989742.0
# 29999  https://www.ncbi.nlm.nih.gov/pubmed/32415494/;...  218642615.0
#
#       abstract_y                                        body_text_x  \
# 0             na                                                NaN
# 8             na  The COVID-19 pandemic has caused a huge number...
# 11            na  Press release from the French National Academy...
# 12            na  Ferrets can manifest with neurologic signs as ...
# 18            na                                                NaN
# ...          ...                                                ...
# 29986         na  • I: Population health is central to addressin...
# 29988         na  . CC-BY-ND 4.0 International license It is mad...
# 29990         na  The coronavirus disease 2019 (COVID-19) has br...
# 29997         na  Indikatoren zum Infektionsgeschehen wie zum in...
# 29999         na                                                NaN
#
#                                              body_text_y
# 0      mRNA-based therapies and vaccines hold tremend...
# 8      The COVID-19 pandemic has caused a huge number...
# 11                                                   NaN
# 12     Neurologic examination of ferrets follows the ...
# 18     The ability to rapidly estimate the probabilit...
# ...                                                  ...
# 29986  It has been more than a half-century since Dr....
# 29988                                                NaN
# 29990  When lockdown in Germany started on 13 March 2...
# 29997  Indikatoren zum Infektionsgeschehen wie zum in...
# 29999  The most common comorbidities reported in epid...
#
# [10170 rows x 22 columns]

# %%
# replace abstract_x (metadata column) with abstract_y (pdf_json) value where abstract_x is null
df_merged.loc[df_merged.abstract_x.isnull() & (df_merged.abstract_y != 'na'),'abstract_x'] = df_merged[df_merged.abstract_x.isnull() & (df_merged.abstract_y != 'na')].abstract_y

# %%
# Do we have any remaining null abstract values. Not anymore. This is good.
# The null values have reduced which is what we had expected.
df_merged.abstract_x.isnull().sum()
# Out:
# 3550

# %%
# Lets get rid of the pdf_json abstract column and rename the metadata abstract column
df_merged.rename(columns = {'abstract_x' : 'abstract'}, inplace = True)
df_merged.drop('abstract_y',axis=1,inplace = True)
df_merged.columns
# Out:
# Index(['cord_uid', 'sha', 'source_x', 'title', 'doi', 'pmcid', 'pubmed_id',
#        'license', 'abstract', 'publish_time', 'authors', 'journal', 'mag_id',
#        'who_covidence_id', 'arxiv_id', 'pdf_json_files', 'pmc_json_files',
#        'url', 's2_id', 'body_text_x', 'body_text_y'],
#       dtype='object')

# %%
# This is expected because body text comes from pdf and pmc folders
(df_merged.body_text_x != df_merged.body_text_y).sum()
# Out:
# 30000

# %%
df_merged.body_text_x.isnull().sum(),(df_merged.body_text_y == '').sum()
# Out:
# (1836, 0)

# %%
# This is expected because there are less papers in json_pmc
df_merged.body_text_y.isnull().sum()
# Out:
# 6402

# %%
# body_text_x is pdf_json. body_text_y comes from pmc_json
# Where available we use the text from pmc file trusting the statement quality
df_merged.body_text_x.isnull().sum(),(df_merged.body_text_y.isnull()).sum()
# Out:
# (1836, 6402)

# %%
# There are ~13k rows where body_text_x is null but body_text_y is not null
df_merged.loc[df_merged.body_text_x.isnull() & df_merged.body_text_y.notnull()]
# Out:
#        cord_uid                                                sha  \
# 0      iyyq4idj  82df15cd2620c224affd4ce100e7fac7fcff7b10; 67f7...
# 18     jmdxjpyq  1928a032224b22aa192550c7e58dc71e190901df; b6cf...
# 21     y0d9l0s9  9f2609078b7d4c36600263ab90e928d300b76e76; abbe...
# 28     s7rtmf6i  2911aa443294c9d9564ce05b8e486463ef8ed85b; 23d3...
# 52     ea33sn1n  200a4d03ea5fc5e4593c34facb38986a77c7b6d2; cc1c...
# ...         ...                                                ...
# 29932  f9uu0o1h  bc1935141cf358405681f33f16bb8b612f46d7a9; d39e...
# 29944  eeeohqjn  6717b875243cf87b395f70f3ec23d8e9f0e8a2c7; 6a20...
# 29965  35k4065e  1c60d93cd686bb14fac65510ad3de47cf8b9332c; 8ee7...
# 29984  fw6pij9h  3a319ff1900a812347b31b899f24694a3ae2bf7a; 231e...
# 29999  o40ey199  20ccde51feef6bc97b383a9a53f17ef09e8de1a5; 8d63...
#
#                           source_x  \
# 0                     Medline; PMC
# 18                    Medline; PMC
# 21                    Medline; PMC
# 28     Elsevier; Medline; PMC; WHO
# 52     Elsevier; Medline; PMC; WHO
# ...                            ...
# 29932       Elsevier; Medline; PMC
# 29944       Elsevier; Medline; PMC
# 29965                 Medline; PMC
# 29984                 Medline; PMC
# 29999                 Medline; PMC
#
#                                                    title  \
# 0      Deconvoluting Lipid Nanoparticle Structure for...
# 18     Clinical prediction rule for SARS-CoV-2 infect...
# 21     Inclusion of cGAMP within virus‐like particle ...
# 28     Real Masks and Spoof Faces: On the Masked Face...
# 52     Understanding the Effects of the COVID-19 Pand...
# ...                                                  ...
# 29932  False negative rate of COVID-19 is eliminated ...
# 29944  Coronaviruses, cholesterol and statins: Involv...
# 29965  Characterization of the Anti-Hepatitis C Virus...
# 29984  Risk factors for poor outcomes in hospitalised...
# 29999  COVID-19 pandemic and therapy with ibuprofen o...
#
#                                 doi       pmcid   pubmed_id license  \
# 0      10.1021/acs.nanolett.0c01386  PMC7228479  32375002.0   no-cc
# 18     10.1371/journal.pone.0248438  PMC7946184  33690722.0   cc-by
# 21          10.15252/embr.202152447  PMC8339669  34142428.0   cc-by
# 28     10.1016/j.patcog.2021.108398  PMC8547786  34720199.0   no-cc
# 52     10.1016/j.bpsgos.2021.07.004  PMC8415869  34514460.0   no-cc
# ...                             ...         ...         ...     ...
# 29932   10.1016/j.tmaid.2020.101668  PMC7151360  32283215.0   no-cc
# 29944  10.1016/j.biochi.2021.06.005  PMC8213520  34153377.0   no-cc
# 29965          10.1128/aac.00126-18  PMC6021681  29760125.0   cc-by
# 29984         10.7189/jogh.11.10001  PMC7980087  33767855.0   cc-by
# 29999    10.1007/s00210-020-01890-6  PMC7225250  32415494.0   cc-by
#
#                                                 abstract publish_time  ...  \
# 0      [Image: see text] Lipid nanoparticle (LNP) pac...   2020-05-06  ...
# 18     OBJECTIVES: Accurate and reliable criteria to ...   2021-03-10  ...
# 21     Cyclic GMP‐AMP (cGAMP) is an immunostimulatory...   2021-06-18  ...
# 28     Face masks have become one of the main methods...   2021-10-26  ...
# 52     BACKGROUND: Adversity has consistently been fo...   2021-07-23  ...
# ...                                                  ...          ...  ...
# 29932                                                NaN   2020-04-11  ...
# 29944  The infectious power of coronaviruses is depen...   2021-06-18  ...
# 29965  Although members of the Flaviviridae display h...   2018-06-26  ...
# 29984  BACKGROUND: Understanding the risk factors for...   2021-03-01  ...
# 29999  Scientists hypothesized that drugs such as ibu...   2020-05-15  ...
#
#                                    journal mag_id  who_covidence_id arxiv_id  \
# 0                                Nano Lett    NaN               NaN      NaN
# 18                                PLoS One    NaN               NaN      NaN
# 21                                EMBO Rep    NaN               NaN      NaN
# 28                        Pattern Recognit    NaN               NaN      NaN
# 52           Biol Psychiatry Glob Open Sci    NaN               NaN      NaN
# ...                                    ...    ...               ...      ...
# 29932                Travel Med Infect Dis    NaN               NaN      NaN
# 29944                            Biochimie    NaN               NaN      NaN
# 29965          Antimicrob Agents Chemother    NaN               NaN      NaN
# 29984             Journal of global health    NaN               NaN      NaN
# 29999  Naunyn Schmiedebergs Arch Pharmacol    NaN               NaN      NaN
#
#                                           pdf_json_files  \
# 0      document_parses/pdf_json/82df15cd2620c224affd4...
# 18     document_parses/pdf_json/1928a032224b22aa19255...
# 21     document_parses/pdf_json/9f2609078b7d4c3660026...
# 28     document_parses/pdf_json/2911aa443294c9d9564ce...
# 52     document_parses/pdf_json/200a4d03ea5fc5e4593c3...
# ...                                                  ...
# 29932  document_parses/pdf_json/bc1935141cf358405681f...
# 29944  document_parses/pdf_json/6717b875243cf87b395f7...
# 29965  document_parses/pdf_json/1c60d93cd686bb14fac65...
# 29984  document_parses/pdf_json/3a319ff1900a812347b31...
# 29999  document_parses/pdf_json/20ccde51feef6bc97b383...
#
#                                      pmc_json_files  \
# 0      document_parses/pmc_json/PMC7228479.xml.json
# 18     document_parses/pmc_json/PMC7946184.xml.json
# 21     document_parses/pmc_json/PMC8339669.xml.json
# 28     document_parses/pmc_json/PMC8547786.xml.json
# 52     document_parses/pmc_json/PMC8415869.xml.json
# ...                                             ...
# 29932  document_parses/pmc_json/PMC7151360.xml.json
# 29944  document_parses/pmc_json/PMC8213520.xml.json
# 29965  document_parses/pmc_json/PMC6021681.xml.json
# 29984  document_parses/pmc_json/PMC7980087.xml.json
# 29999  document_parses/pmc_json/PMC7225250.xml.json
#
#                                                      url        s2_id  \
# 0      https://doi.org/10.1021/acs.nanolett.0c01386; ...  218535340.0
# 18     https://www.ncbi.nlm.nih.gov/pubmed/33690722/;...  232193176.0
# 21     https://www.ncbi.nlm.nih.gov/pubmed/34142428/;...  235473166.0
# 28     https://www.sciencedirect.com/science/article/...  239890411.0
# 52     https://api.elsevier.com/content/article/pii/S...  237403375.0
# ...                                                  ...          ...
# 29932  https://www.ncbi.nlm.nih.gov/pubmed/32283215/;...  215724665.0
# 29944  https://api.elsevier.com/content/article/pii/S...  235473780.0
# 29965  https://doi.org/10.1128/aac.00126-18; https://...   46890746.0
# 29984  https://doi.org/10.7189/jogh.11.10001; https:/...  232336581.0
# 29999  https://www.ncbi.nlm.nih.gov/pubmed/32415494/;...  218642615.0
#
#        body_text_x                                        body_text_y
# 0              NaN  mRNA-based therapies and vaccines hold tremend...
# 18             NaN  The ability to rapidly estimate the probabilit...
# 21             NaN  Vaccination is a powerful strategy in the figh...
# 28             NaN  Since the SARS-CoV-2 coronavirus outbreak and ...
# 52             NaN  Past work has indicated that adversity has a p...
# ...            ...                                                ...
# 29932          NaN  This study was approved by the Ethics Committe...
# 29944          NaN  The present Covid-19 pandemic has revealed to ...
# 29965          NaN  Urbanization, human migrations, and climate ch...
# 29984          NaN  The search strategy was designed to identify s...
# 29999          NaN  The most common comorbidities reported in epid...
#
# [1739 rows x 21 columns]

# %%
# We are trusting the text from pmc folder to be of higher quality as it contains full text. 
# Hence we will replace with body_text_x with body_text_y where body_text_y exists
df_merged.loc[df_merged.body_text_y.notnull(),'body_text_x'] = df_merged.loc[df_merged.body_text_y.notnull(), 'body_text_y']

# %%
# Lets get rid of the pdf_pmc body text column and rename the body text column
df_merged.rename(columns = {'body_text_x' : 'body_text'}, inplace = True)
df_merged.drop('body_text_y',axis=1,inplace = True)
df_merged.columns
# Out:
# Index(['cord_uid', 'sha', 'source_x', 'title', 'doi', 'pmcid', 'pubmed_id',
#        'license', 'abstract', 'publish_time', 'authors', 'journal', 'mag_id',
#        'who_covidence_id', 'arxiv_id', 'pdf_json_files', 'pmc_json_files',
#        'url', 's2_id', 'body_text'],
#       dtype='object')

# %%
# Body text null values have now decreased.
df_merged.body_text.isnull().sum()
# Out:
# 97

# %%
df_merged.columns
# Out:
# Index(['cord_uid', 'sha', 'source_x', 'title', 'doi', 'pmcid', 'pubmed_id',
#        'license', 'abstract', 'publish_time', 'authors', 'journal', 'mag_id',
#        'who_covidence_id', 'arxiv_id', 'pdf_json_files', 'pmc_json_files',
#        'url', 's2_id', 'body_text'],
#       dtype='object')

# %%
df_final = df_merged[['sha', 'title', 'abstract', 'publish_time', 'authors', 'url', 'body_text']]

# %%
df_final.head()
# Out:
#                                                  sha  \
# 0  82df15cd2620c224affd4ce100e7fac7fcff7b10; 67f7...
# 1           1e7e71936cb8aa74a8c9e8ba90c5d729dec7f405
# 2           cc4e338a21138f18ef26af7b26c5ecc28270d959
# 3           3114420bfc07e18049a9e7045b42c4de7a30bb81
# 4           1ef3ec3dfb9bea22c1060c1c469fc1de5c41f15a
#
#                                                title  \
# 0  Deconvoluting Lipid Nanoparticle Structure for...
# 1            Predictability in Contemporary Medicine
# 2  Experimental Models of Hepatocellular Carcinom...
# 3  Cancer and COVID-19: analysis of patient outcomes
# 4  Haematuria, a widespread petechial rash, and h...
#
#                                             abstract publish_time  \
# 0  [Image: see text] Lipid nanoparticle (LNP) pac...   2020-05-06
# 1  Medical practice is increasingly coming under ...   2021-06-16
# 2  SIMPLE SUMMARY: Hepatocellular carcinoma (HCC)...   2021-07-21
# 3  Background: We sought to investigate the outco...   2021-07-15
# 4  With increasing presentations of headaches fol...   2021-10-07
#
#                                              authors  \
# 0  Eygeris, Yulia; Patel, Siddharth; Jozic, Anton...
# 1                                 Ciulla, Michele M.
# 2  Blidisel, Alexandru; Marcovici, Iasmina; Coric...
# 3  Aboueshia, Mohamed; Hussein, Mohammad Hosny; A...
# 4                   Waraich, Ammar; Williams, George
#
#                                                  url  \
# 0  https://doi.org/10.1021/acs.nanolett.0c01386; ...
# 1  https://www.ncbi.nlm.nih.gov/pubmed/34222267/;...
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8...
# 3  https://www.ncbi.nlm.nih.gov/pubmed/34263660/;...
# 4  https://www.ncbi.nlm.nih.gov/pubmed/34620638/;...
#
#                                            body_text
# 0  mRNA-based therapies and vaccines hold tremend...
# 1  The aim of this paper is to present in a histo...
# 2  Hepatocellular carcinoma (HCC), the most commo...
# 3  Study data were collected and managed using RE...
# 4  With increasing presentations of patients with...

# %%
df_final = df_final.dropna(axis=0,subset=['body_text', 'title'])
df_final.isnull().sum()
# Out:
# sha                0
# title              0
# abstract        3535
# publish_time       0
# authors          274
# url                0
# body_text          0
# dtype: int64

# %%
df_final.shape
# Out:
# (29902, 7)

# %%
df_final.to_csv('data/FINAL_CORD_DATA.csv', index=False)
